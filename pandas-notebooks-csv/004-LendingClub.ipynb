# %%
# %matplotlib inline

import pandas as pd
import numpy as np
LD = pd.read_csv('/home/sophie/projects/LendingClub/data/loansData.csv')

# %% [markdown]
# My aim was to cut out the 95th percentiles data and save as a new array, but only got as far as making a few plots.

# %%
#what format are each of the columns

LD.dtypes
# Out:
# Amount.Requested                    int64
# Amount.Funded.By.Investors        float64
# Interest.Rate                      object
# Loan.Length                        object
# Loan.Purpose                       object
# Debt.To.Income.Ratio               object
# State                              object
# Home.Ownership                     object
# Monthly.Income                    float64
# FICO.Range                         object
# Open.CREDIT.Lines                 float64
# Revolving.CREDIT.Balance          float64
# Inquiries.in.the.Last.6.Months    float64
# Employment.Length                  object
# dtype: object

# %%
len(LD['Amount.Requested'].unique())
print LD['Amount.Requested'].describe(percentiles=[.05,.5,.95])
LD['Amount.Requested'].plot(kind='box')
LD['Amount.Requested'].hist()
# Out:
# count     2500.000000
# mean     12406.500000
# std       7801.544872
# min       1000.000000
# 5%        2871.250000
# 50%      10000.000000
# 95%      28000.000000
# max      35000.000000
# Name: Amount.Requested, dtype: float64

# %%
LD['Amount.Requested'].hist()
_ = LD.hist(figsize=(10,10),xlabelsize=(6.5))

# %%
#some description of what this does can be found here: 
#http://rallion.bitbucket.org/explorations/machine_learning/api/pandas.tools.plotting.scatter_matrix.html
from pandas.tools.plotting import scatter_matrix

_ = scatter_matrix(LD, alpha=0.5, figsize=(12,12),diagonal='kde')

# %% [markdown]
# The diagonal plots above are the density functions for that variable ^^^

# %%
LDNull = LD[LD['Employment.Length'].isin(['n/a'])]
print LD.max()
LDNull.max()
# Out:
# Amount.Requested                      35000
# Amount.Funded.By.Investors            35000
# Interest.Rate                         9.99%
# Loan.Length                       60 months
# Loan.Purpose                        wedding
# Debt.To.Income.Ratio                  9.99%
# State                                    WY
# Home.Ownership                         RENT
# Monthly.Income                       102750
# FICO.Range                          830-834
# Open.CREDIT.Lines                        38
# Revolving.CREDIT.Balance             270800
# Inquiries.in.the.Last.6.Months            9
# Employment.Length                       n/a
# dtype: object
# Amount.Requested                      35000
# Amount.Funded.By.Investors            35000
# Interest.Rate                         9.99%
# Loan.Length                       60 months
# Loan.Purpose                        wedding
# Debt.To.Income.Ratio                  9.61%
# State                                    WV
# ...
